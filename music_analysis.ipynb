# %%
import pyarrow.parquet as pa
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#) reading parquet file
table = pa.read_table(r"D:\Sudharsan\Guvi_Data science\DS101_Sudharsan\Mainboot camp\capstone project\final_project\0000 (1).parquet") 
table
# Out:
# pyarrow.Table
# Unnamed: 0: int64
# track_id: string
# artists: string
# album_name: string
# track_name: string
# popularity: int64
# duration_ms: int64
# explicit: bool
# danceability: double
# energy: double
# key: int64
# loudness: double
# mode: int64
# speechiness: double
# acousticness: double
# instrumentalness: double
# liveness: double
# valence: double
# tempo: double
# time_signature: int64
# track_genre: string
# ----
# Unnamed: 0: [[0,1,2,3,4,...,995,996,997,998,999],[1000,1001,1002,1003,1004,...,1995,1996,1997,1998,1999],...,[112000,112001,112002,112003,112004,...,112995,112996,112997,112998,112999],[113000,113001,113002,113003,113004,...,113995,113996,113997,113998,113999]]
# ...

# %%
#) to count columns and rows
table.shape
# Out:
# (114000, 21)

# %%
#) converting table to pandas
df = table.to_pandas() 
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
#) to get info of dataframe
df.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
#) to get describe of dataframe
df.describe
# Out:
# <bound method NDFrame.describe of         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
#) to get column name
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
#) to check the columns with data
df[['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name']]
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
#) unique in artist column
df['artists'].unique()
# Out:
# array(['Gen Hoshino', 'Ben Woodward', 'Ingrid Michaelson;ZAYN', ...,
#        'Cuencos Tibetanos Sonidos Relajantes',
#        'Bryan & Katie Torwalt;Brock Human', 'Jesus Culture'], dtype=object)

# %%
#) unique in album column
df['album_name'].unique()
# Out:
# array(['Comedy', 'Ghost (Acoustic)', 'To Begin Again', ...,
#        '#20 Sueños Vividos - Música Intrumental Suave 2018 para Dormir Bien y Relajarse Profundamente',
#        'Frecuencias Álmicas en 432hz (Solo Piano)', 'Revelation Songs'],
#       dtype=object)

# %%
#) unique in track column
df['track_name'].unique()
# Out:
# array(['Comedy', 'Ghost - Acoustic', 'To Begin Again', ...,
#        'Water Into Light', 'Miss Perfumado', 'Barbincor'], dtype=object)

# %%
#) to check the columns with data
df[['popularity','duration_ms','explicit','danceability','energy']]
# Out:
#         popularity  duration_ms  explicit  danceability  energy
# 0               73       230666     False         0.676  0.4610
# 1               55       149610     False         0.420  0.1660
# 2               57       210826     False         0.438  0.3590
# 3               71       201933     False         0.266  0.0596
# 4               82       198853     False         0.618  0.4430
# ...            ...          ...       ...           ...     ...
# 113995          21       384999     False         0.172  0.2350
# 113996          22       385000     False         0.174  0.1170
# 113997          22       271466     False         0.629  0.3290
# 113998          41       283893     False         0.587  0.5060
# 113999          22       241826     False         0.526  0.4870
#
# [114000 rows x 5 columns]

# %%
#) to check the columns with data
df[['key', 'loudness', 'mode', 'speechiness', 'acousticness','instrumentalness']]
# Out:
#         key  loudness  mode  speechiness  acousticness  instrumentalness
# 0         1    -6.746     0       0.1430        0.0322          0.000001
# 1         1   -17.235     1       0.0763        0.9240          0.000006
# 2         0    -9.734     1       0.0557        0.2100          0.000000
# 3         0   -18.515     1       0.0363        0.9050          0.000071
# 4         2    -9.681     1       0.0526        0.4690          0.000000
# ...     ...       ...   ...          ...           ...               ...
# 113995    5   -16.393     1       0.0422        0.6400          0.928000
# 113996    0   -18.318     0       0.0401        0.9940          0.976000
# 113997    0   -10.895     0       0.0420        0.8670          0.000000
# 113998    7   -10.889     1       0.0297        0.3810          0.000000
# 113999    1   -10.204     0       0.0725        0.6810          0.000000
#
# [114000 rows x 6 columns]

# %%
#) to check the columns with data
df[['liveness', 'valence', 'tempo', 'time_signature','track_genre']]
# Out:
#         liveness  valence    tempo  time_signature  track_genre
# 0         0.3580   0.7150   87.917               4     acoustic
# 1         0.1010   0.2670   77.489               4     acoustic
# 2         0.1170   0.1200   76.332               4     acoustic
# 3         0.1320   0.1430  181.740               3     acoustic
# 4         0.0829   0.1670  119.949               4     acoustic
# ...          ...      ...      ...             ...          ...
# 113995    0.0863   0.0339  125.995               5  world-music
# 113996    0.1050   0.0350   85.239               4  world-music
# 113997    0.0839   0.7430  132.378               4  world-music
# 113998    0.2700   0.4130  135.960               4  world-music
# 113999    0.0893   0.7080   79.198               4  world-music
#
# [114000 rows x 5 columns]

# %%
#) to get unique in track_genre column 
df['track_genre'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
#) scatterplot 1 - duration vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ="duration_ms",y= "popularity",hue="explicit",style="mode")
plt.show()

# %%
#) observation 1:
#) people mostly like only less time duration music compared to the lengthy music.
#) lyrics not required for popularity.
#) people like both melody and beat songs

# %%
df["duration_ms"].max()
# Out:
# 5237295

# %%
#) scatterplot 2 - danceability vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ="danceability",y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#) observation 2:
#) danceability influences popularity. people like more dancability songs.

# %%
#) scatterplot 3 - energy vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ="energy",y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#)observation 3:
#) people like (above average) medium energy songs. high noisy songs are not so much popular.
#) very low tone songs low popularity score

# %%
#) scatterplot 4 - loudness vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ="loudness",y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#) observation 4
#) low loud songs are not popular. high loudness songs are famous.

# %%
#) scatterplot 5 - speechiness vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ='speechiness',y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#) observation 5
#) low speech songs are popular. high speeches in the songs are unpopular

# %%
#) scatterplot 6 - acousticness vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ='acousticness',y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#) observation 6:
#) acoustics do not affect the popularity

# %%
#) scatterplot 7 - instrumentalness vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ='instrumentalness',y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#) observation 7
#) low vocal songs are quite popular. anyway, vocal is not influecing much on the popularity

# %%
#) scatterplot 8 - liveness vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ='liveness',y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#) observation 8
#) live songs are not that much popular

# %%
#) scatterplot 9 - valence vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ='valence',y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#) observation 9
#) emotion in the songs do not influence the popularity.

# %%
#) scatterplot 10 - tempo vs popularity
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x ='tempo',y= 'popularity',hue="explicit",style="mode")
plt.show()
# Out:
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#) observation 10
#) medium beats music is quite famous

# %%
#) to check the null values in pandas
df.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#) filling the null values
df = df.ffill()
df = df.bfill()

# %%
#) to check the null values in pandas
df.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

#df.drop(['Unnamed: 0','track_id','artists','album_name','track_name'],axis=1,inplace=True)
#df = pd.get_dummies(df,['track_genre'])
X = df.drop(['popularity'],axis=1)
y = df['popularity']
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
models = [LinearRegression(),Lasso(),Ridge()]
for model in models:
    model.fit(x_train,y_train)
    train_pred = model.predict(x_train)
    test_pred = model.predict(x_test)
    print(f"********{type(model).__name__}***********")
    print("********Train data*********")
    print(mean_squared_error(y_train,train_pred))
    print("********Test data*********")
    print(mean_squared_error(y_test,test_pred))
# Out:
# ********LinearRegression***********
# ********Train data*********
# 368.5428724325709
# ********Test data*********
# 367.689172367836
# ********Lasso***********
# ********Train data*********
# 495.9282511752331
# ********Test data*********
# 497.6534567096563
# ********Ridge***********
# ********Train data*********
# 368.54307505467415
# ********Test data*********
# 367.6920257054812
